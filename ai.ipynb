# %%
from wordcloud import WordCloud

import pandas as pd

import numpy as np

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer 
import re

from textblob import TextBlob

import seaborn as sns

import matplotlib.pyplot as plt

import cufflinks as cf
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
cf.go_offline();
import plotly.graph_objs as go
from plotly.subplots import make_subplots

import warnings
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df = pd.read_csv('AI_Engineer_Dataset_Task_1.csv')

# %%
df.head()
# Out:
#    AcademicYear      SemesterName  ParticipantID DegreeLevel  Gender  \
# 0          2021  Fall 2021 - 2022     7040336900    Bachelor  Female
# 1          2021  Fall 2021 - 2022     6707335167    Bachelor    Male
# 2          2021  Fall 2021 - 2022     6707335167    Bachelor    Male
# 3          2021  Fall 2021 - 2022     6707335167    Bachelor    Male
# 4          2021  Fall 2021 - 2022     6707335167    Bachelor    Male
#
#             Nationality                       StudentProgram CourseCode  \
# 0             Palestine  Bachelor of Business Administration    ACC 100
# 1  United Arab Emirates  Bachelor of Business Administration    ACC 100
# 2  United Arab Emirates  Bachelor of Business Administration    ACC 100
# 3  United Arab Emirates  Bachelor of Business Administration    ACC 100
# 4  United Arab Emirates  Bachelor of Business Administration    ACC 100
#
#                  CourseName  \
# 0  Principles of Accounting
# 1  Principles of Accounting
# ...

# %%
df
# Out:
#         AcademicYear        SemesterName  ParticipantID DegreeLevel  Gender  \
# 0               2021    Fall 2021 - 2022     7040336900    Bachelor  Female
# 1               2021    Fall 2021 - 2022     6707335167    Bachelor    Male
# 2               2021    Fall 2021 - 2022     6707335167    Bachelor    Male
# 3               2021    Fall 2021 - 2022     6707335167    Bachelor    Male
# 4               2021    Fall 2021 - 2022     6707335167    Bachelor    Male
# ...              ...                 ...            ...         ...     ...
# 180964          2021  Spring 2021 - 2022     7040334533    Bachelor    Male
# 180965          2021  Spring 2021 - 2022     6724000467    Bachelor    Male
# 180966          2022    Fall 2022 - 2023     6373669933    Bachelor    Male
# 180967          2022    Fall 2022 - 2023     6373669933    Bachelor    Male
# 180968          2022    Fall 2022 - 2023     6373669933    Bachelor    Male
#
#                  Nationality  \
# ...

# %%
rt = lambda x: re.sub("[^a-zA-Z]", ' ',str(x))
df["ParticipantResponse"] = df["ParticipantResponse"].map(rt)
df["ParticipantResponse"] = df["ParticipantResponse"].str.lower()
df.head()
# Out:
#    AcademicYear      SemesterName  ParticipantID DegreeLevel  Gender  \
# 0          2021  Fall 2021 - 2022     7040336900    Bachelor  female
# 1          2021  Fall 2021 - 2022     6707335167    Bachelor    male
# 2          2021  Fall 2021 - 2022     6707335167    Bachelor    male
# 3          2021  Fall 2021 - 2022     6707335167    Bachelor    male
# 4          2021  Fall 2021 - 2022     6707335167    Bachelor    male
#
#             Nationality                       StudentProgram CourseCode  \
# 0             Palestine  Bachelor of Business Administration    ACC 100
# 1  United Arab Emirates  Bachelor of Business Administration    ACC 100
# 2  United Arab Emirates  Bachelor of Business Administration    ACC 100
# 3  United Arab Emirates  Bachelor of Business Administration    ACC 100
# 4  United Arab Emirates  Bachelor of Business Administration    ACC 100
#
#                  CourseName  \
# 0  Principles of Accounting
# 1  Principles of Accounting
# ...

# %%
constraints = ['RED','BLUE','YELLOW','GREEN','BLACK']
def categorical_variable_summary(df,column_name):
    fig= make_subplots(rows = 1, cols =2,
                        subplot_titles=('countplot','percentage'),
                        specs=[[{'type': 'xy'},{'type':'domain'}]])
    fig.add_trace(go.Bar(y = df[column_name].value_counts().values.tolist(),
                         x = [str(i) for i in df[column_name].value_counts().index],
                         text =df[column_name].value_counts().values.tolist(),
                         name = column_name,
                         textposition = 'auto',
                        showlegend = False,
                         marker = dict(colors=constraints,
                                     line=dict(colors='white',
                                               width=1))),
                row =1, col =1)

    fig.add_trace(go.Pie(labels = df[column_name].value_counts().keys(),
                         values =df[column_name].value_counts().values,
                         name = column_name,
                         textposition = 'auto',
                        showlegend = False,
                         marker = dict(colors=constraints)),             
                row =1, col =2)
    fig.update_layout(title={'text': column_name,
                            'y':0.9,
                            'x':0.5,
                            'xanchor':'center',
                            'yanchor':'top'},
                     template = 'plotly_white')
    iplot(fig)

# %%
categorical_variable_summary(df, 'AcademicYear')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 categorical_variable_summary(df, 'AcademicYear')
#
# Cell In[63], line 6, in categorical_variable_summary(df, column_name)
#       2 def categorical_variable_summary(df,column_name):
#       3     fig= make_subplots(rows = 1, cols =2,
#       4                         subplot_titles=('countplot','percentage'),
#       5                         specs=[[{'type': 'xy'},{'type':'domain'}]])
# ----> 6     fig.add_trace(go.Bar(y = df[column_name].value_counts().values.tolist(),
#       7                          x = [str(i) for i in df[column_name].value_counts().index],
#       8                          text =df[column_name].value_counts().values.tolist(),
#       9                          name = column_name,
#      10                          textposition = 'auto',
# ...

# %%
def sentiment_calc(text):
    try:
        return TextBlob(text).sentiment
    except:
        return None


df[['polarity' , 'subjectivity']] = df['ParticipantResponse'].apply(lambda Text:pd.Series(sentiment_calc()))

for index, row in df['ParticipantResponse'].iteritems():
        score = SentimentIntensityAnalyzer().polarity.scores(row)

        neg = score['neg']
        neu = score['neu']
        pos = score['pos']

        if neg > pos:
            df.loc[index,'sentiment'] = "Negative"
        elif pos > neg:
            df.loc[index, 'sentiment'] = "Positive"
        else:
            df.loc[index, 'sentiment'] = "Neutral"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       4     except:
#       5         return None
# ----> 8 df[['polarity' , 'subjectivity']] = df['ParticipantResponse'].apply(lambda Text:pd.Series(sentiment_calc()))
#      10 for index, row in df['ParticipantResponse'].iteritems():
#      11         score = SentimentIntensityAnalyzer().polarity.scores(row)
#
# File ~\myenv\Lib\site-packages\pandas\core\series.py:4765, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4756     dtype: float64
#    4757     """
#    4758     return SeriesApply(
#    4759         self,
#    4760         func,
# ...
